# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunjaec/MScA_Deep_Learning_Project/blob/main/map_image_samples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
! ls "/content/drive/My Drive/Data/FireShot/"
# Out:
# 'FireShot Capture 006 - Google Map Customizer - www.chengfolio.com.png'
# 'FireShot Capture 008 - Google Map Customizer - www.chengfolio.com.png'

# %%
img = cv2.imread("/content/drive/My Drive/Data/FireShot/FireShot Capture 008 - Google Map Customizer - www.chengfolio.com.png")

# %%
img.shape
# Out:
# (5768, 5768, 3)

# %%
dim = (5700, 5700)

# %%
cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
# Out:
# array([[[206, 207, 210],
#         [211, 212, 215],
#         [211, 211, 216],
#         ...,
#         [214, 220, 215],
#         [205, 211, 206],
#         [195, 202, 197]],
#
#        [[184, 185, 188],
#         [193, 193, 198],
#         [198, 198, 203],
#         ...,
#         [215, 221, 216],
#         [203, 210, 205],
#         [191, 198, 193]],
#
#        [[155, 156, 159],
#         [166, 166, 171],
#         [174, 174, 180],
#         ...,
#         [219, 225, 220],
#         [207, 213, 208],
#         [194, 202, 197]],
#
#        ...,
#
#        [[101, 101,  87],
#         [100, 100,  86],
#         [102, 101,  87],
#         ...,
#         [ 99, 119, 102],
#         [100, 119, 104],
#         [ 99, 119, 102]],
#
#        [[105, 103,  90],
#         [101,  99,  86],
#         [ 98,  96,  83],
#         ...,
#         [ 97, 118, 104],
#         [ 99, 120, 106],
#         [100, 120, 106]],
#
#        [[110, 107,  94],
#         [104, 101,  90],
#         [ 99,  96,  83],
# ...

# %%
tiles = [img[x:x+200,y:y+200] for x in range(0,img.shape[0],200) for y in range(0,img.shape[1],200)]

# %%
len(tiles)
# Out:
# 841

# %%
import matplotlib.pyplot as plt

# %%
f, axarr = plt.subplots(3,4,  figsize=(15, 15))
axarr[0,0].imshow(tiles[0])
axarr[0,1].imshow(tiles[1])
axarr[0,2].imshow(tiles[2])
axarr[0,3].imshow(tiles[3])
axarr[1,0].imshow(tiles[4])
axarr[1,1].imshow(tiles[5])
axarr[1,2].imshow(tiles[6])
axarr[1,3].imshow(tiles[7])
axarr[2,0].imshow(tiles[8])
axarr[2,1].imshow(tiles[9])
axarr[2,2].imshow(tiles[10])
axarr[2,3].imshow(tiles[11])
