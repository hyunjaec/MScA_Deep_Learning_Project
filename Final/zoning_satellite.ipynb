# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunjaec/MScA_Deep_Learning_Project/blob/main/zoning_satellite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
from scipy import ndimage, signal as sg
from skimage import data, filters, io, color
from sklearn.model_selection import train_test_split
from PIL import Image
import glob
import cv2
from google.colab.patches import cv2_imshow
import keras
from keras.datasets import mnist
from keras import optimizers
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten,BatchNormalization, Input, ZeroPadding2D
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import applications
from skimage.filters.rank import median, mean

import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
# !pwd
# Out:
# /content

# %%
#connect colab with google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#label csv
austin_df = pd.read_csv("/content/drive/My Drive/Data/data/austin.csv")
austin_df = austin_df.drop('Unnamed: 0', axis = 1)
austin_df.head()
# Out:
#           image_name  zoning_id zoning_zty
# 0  data/austin_0.jpg     229791        PUD
# 1  data/austin_1.jpg     229791        PUD
# 2  data/austin_2.jpg  400523442       I-RR
# 3  data/austin_3.jpg     229791        PUD
# 4  data/austin_4.jpg     229791        PUD

# %%
residential = ['LA',
            'RR',
            'SF-1',
            'SF-2',
            'SF-3',
            'SF-4A',
            'SF-4-A,'
            'SF-4B',
            'SF-5',
            'SF-6',
            'MF-1',
            'MF-2',
            'MF-3',
            'MF-4',
            'MF-5',
            'MF-6',
            'MF-CO',
            'MH']

commercial = ['NO',
            'LO',
            'GO',
            'CR',
            'LR',
            'GR',
            'L',
            'CBD',
            'DMU',
            'W/LO',
            'CS',
            'CS-1',
            'CH']

industrial = ['IP', 'LI', 'MI', 'R&D']

special = ['DR', 'AV', 'AG', 'P', 'PUD', 'TN', 'ERC', 'UNZ']

# %%
#loop through list of zone codes, map specific zone codes to R, C, I, or S
austin_df.loc[:, 'zone'] = np.nan

for i in residential:
    austin_df.loc[:, 'zone'] = np.where(austin_df.loc[:, 'zoning_zty'].str.contains(i) == True, 
                                     'R', austin_df.loc[:,'zone'])
for i in industrial:
    austin_df.loc[:, 'zone'] = np.where(((austin_df.loc[:, 'zoning_zty'].str.contains(i) == True) & (austin_df.loc[:, 'zone'] != 'R')), 
                                     'I', austin_df.loc[:,'zone'])
for i in commercial:
    austin_df.loc[:, 'zone'] = np.where((austin_df.loc[:, 'zoning_zty'].str.contains(i) == True) & \
                                     (austin_df.loc[:, 'zone'] != 'R') & (austin_df.loc[:, 'zone'] != 'I'), 
                                     'C', austin_df.loc[:,'zone'])
for i in special:
    austin_df.loc[:, 'zone'] = np.where((austin_df.loc[:, 'zoning_zty'].str.contains(i) == True) & \
                                     (austin_df.loc[:, 'zone'] != 'I') & (austin_df.loc[:, 'zone'] != 'R') &\
                                     (austin_df.loc[:, 'zone'] != 'C'), 
                                     'S', austin_df.loc[:,'zone'])

# %%
#manually set this one
austin_df.loc[303, 'zone'] = 'R'

# %%
austin_df.head()
# Out:
#           image_name  zoning_id zoning_zty zone
# 0  data/austin_0.jpg     229791        PUD    S
# 1  data/austin_1.jpg     229791        PUD    S
# 2  data/austin_2.jpg  400523442       I-RR    R
# 3  data/austin_3.jpg     229791        PUD    S
# 4  data/austin_4.jpg     229791        PUD    S

# %%
plt.hist(austin_df['zone'])
# Out:
# (array([1235.,    0.,    0., 1747.,    0.,    0.,  446.,    0.,    0.,
#          239.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)

# %%
img_names = austin_df['image_name']

# %%
dim = (200, 200)

# %%
# img_df = []
# # for i in img_names:
# #     img_df.append(cv2.imread(('../'+ str(i))))
# for i, img in enumerate(img_names):
#     visual_img = image.load_img(('/content/drive/My Drive/Data/'+img), target_size=dim)  
#     img_array = image.img_to_array(visual_img)
#     img_array = median(img_array, 1.0/9.0 * np.ones((3, 3)))
#     img_df.append(img_array)

# %%
dim = (200, 200)
img_df = []
for i in img_names:
  visual_img = cv2.imread("/content/drive/My Drive/Data/" + str(i[:-4])+".jpg")
  visual_img = cv2.resize(visual_img, dim, interpolation = cv2.INTER_AREA)
  visual_img = cv2.fastNlMeansDenoisingColored(visual_img,None,10,10,7,15)
  img_df.append(visual_img)

# %%
img_array = np.array(img_df) 
img_array.shape
# Out:
# (3667, 200, 200, 3)

# %%
#make images equal pixel by 500, 500 
# for i, img in enumerate(img_df):
#   img_df[i] = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

# %%
cv2_imshow(img_array[53])
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F5AD2027750>

# %%
fig, ax = plt.subplots(1, 4, figsize=(15, 15), sharex=True, sharey=True)
ax1, ax2, ax3, ax4 = ax.ravel()

ax1.imshow(np.array(img_array[53],np.int32))
ax1.set_title('Residential')

ax2.imshow(np.array(img_array[138],np.int32))
ax2.set_title('Commercial')

ax3.imshow(np.array(img_array[397],np.int32))
ax3.set_title('Industrial')

ax4.imshow(np.array(img_array[72],np.int32))
ax4.set_title('Special')


plt.show()

# %%
img_df2 = np.array(img_df) 
zone_class = np.array(austin_df['zone']) 
zone_class = pd.get_dummies(zone_class)
#split labels and images for train&test
X_train, X_test, y_train, y_test = train_test_split(img_df2, zone_class, test_size=.15)
input_shape = (200, 200, 3)

# %%
datagen = ImageDataGenerator(
#     rotation_range=30,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     horizontal_flip=True,
#     validation_split=0.2
    rescale=1.0/255,
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
    )

datagen.fit(X_train)

# %%
model = Sequential()
model.add(Conv2D(128, kernel_size=(3, 3),
                 activation='relu', 
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(200, activation='relu'))
model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 128)     3584
#
#  conv2d_1 (Conv2D)           (None, 196, 196, 64)      73792
#
#  batch_normalization (BatchN  (None, 196, 196, 64)     256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 98, 98, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 96, 96, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 147456)            0
#
#  dense (Dense)               (None, 200)               29491400
#
#  dense_1 (Dense)             (None, 4)                 804
#
# =================================================================
# Total params: 29,607,020
# Trainable params: 29,606,764
# Non-trainable params: 256
# _________________________________________________________________

# %%
# model = applications.efficientnet_v2.EfficientNetV2L(weights = "imagenet", include_top=False, input_shape = (200, 200, 3))

# %%
#model.summary()

# %%
# x = model.output
# x = Flatten()(x)
# x = Dense(1024, activation="relu")(x)
# x = Dropout(0.5)(x)
# x = Dense(1024, activation="relu")(x)
# predictions = Dense(4, activation="softmax")(x)

# # creating the final model 
# model_final = Model(model.input, predictions)

# %%
#model_final.summary()

# %%
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=0.0001), loss=keras.losses.categorical_crossentropy, metrics=["accuracy"])

# %%
batch_size = 64
epochs = 50

# %%
X_test.shape
# Out:
# (551, 200, 200, 3)

# %%
history = model.fit(datagen.flow(X_train, y_train, batch_size=batch_size, subset='training'), 
                    validation_data=datagen.flow(X_train, y_train, subset='validation'),
                    epochs=epochs)
# Out:
# Epoch 1/50
# 39/39 [==============================] - 37s 784ms/step - loss: 2.3488 - accuracy: 0.5102 - val_loss: 2.8947 - val_accuracy: 0.2408
# Epoch 2/50
# 39/39 [==============================] - 25s 632ms/step - loss: 1.0359 - accuracy: 0.5804 - val_loss: 2.3832 - val_accuracy: 0.3210
# Epoch 3/50
# 39/39 [==============================] - 25s 629ms/step - loss: 0.9602 - accuracy: 0.6093 - val_loss: 4.1522 - val_accuracy: 0.3242
# Epoch 4/50
# 39/39 [==============================] - 25s 638ms/step - loss: 0.9419 - accuracy: 0.6133 - val_loss: 6.0575 - val_accuracy: 0.2424
# Epoch 5/50
# 39/39 [==============================] - 25s 638ms/step - loss: 0.9305 - accuracy: 0.6193 - val_loss: 5.1311 - val_accuracy: 0.1782
# Epoch 6/50
# 39/39 [==============================] - 25s 642ms/step - loss: 0.9095 - accuracy: 0.6229 - val_loss: 4.6468 - val_accuracy: 0.2472
# Epoch 7/50
# 39/39 [==============================] - 25s 635ms/step - loss: 0.9133 - accuracy: 0.6233 - val_loss: 4.7965 - val_accuracy: 0.2937
# Epoch 8/50
# 39/39 [==============================] - 25s 636ms/step - loss: 0.9029 - accuracy: 0.6278 - val_loss: 6.5707 - val_accuracy: 0.2408
# Epoch 9/50
# 39/39 [==============================] - 25s 636ms/step - loss: 0.9030 - accuracy: 0.6278 - val_loss: 2.7512 - val_accuracy: 0.4671
# Epoch 10/50
# 39/39 [==============================] - 26s 654ms/step - loss: 0.9141 - accuracy: 0.6274 - val_loss: 5.4071 - val_accuracy: 0.2905
# Epoch 11/50
# 39/39 [==============================] - 25s 644ms/step - loss: 0.8879 - accuracy: 0.6378 - val_loss: 3.2698 - val_accuracy: 0.4543
# Epoch 12/50
# 39/39 [==============================] - 25s 627ms/step - loss: 0.9046 - accuracy: 0.6334 - val_loss: 3.7808 - val_accuracy: 0.3210
# Epoch 13/50
# 39/39 [==============================] - 25s 632ms/step - loss: 0.8865 - accuracy: 0.6334 - val_loss: 1.2111 - val_accuracy: 0.5522
# Epoch 14/50
# 39/39 [==============================] - 25s 626ms/step - loss: 0.8914 - accuracy: 0.6306 - val_loss: 1.0672 - val_accuracy: 0.5522
# Epoch 15/50
# 39/39 [==============================] - 28s 715ms/step - loss: 0.8950 - accuracy: 0.6330 - val_loss: 1.3214 - val_accuracy: 0.5522
# Epoch 16/50
# 39/39 [==============================] - 25s 625ms/step - loss: 0.8942 - accuracy: 0.6386 - val_loss: 1.1256 - val_accuracy: 0.4912
# Epoch 17/50
# 39/39 [==============================] - 25s 641ms/step - loss: 0.8756 - accuracy: 0.6382 - val_loss: 0.9656 - val_accuracy: 0.6035
# Epoch 18/50
# 39/39 [==============================] - 24s 621ms/step - loss: 0.8654 - accuracy: 0.6426 - val_loss: 1.0484 - val_accuracy: 0.5939
# Epoch 19/50
# 39/39 [==============================] - 25s 636ms/step - loss: 0.9063 - accuracy: 0.6342 - val_loss: 7.3157 - val_accuracy: 0.3403
# Epoch 20/50
# 39/39 [==============================] - 25s 631ms/step - loss: 0.8898 - accuracy: 0.6358 - val_loss: 5.4439 - val_accuracy: 0.3820
# Epoch 21/50
# 39/39 [==============================] - 25s 630ms/step - loss: 0.8721 - accuracy: 0.6298 - val_loss: 0.9453 - val_accuracy: 0.6132
# Epoch 22/50
# 39/39 [==============================] - 25s 630ms/step - loss: 0.8752 - accuracy: 0.6450 - val_loss: 1.5595 - val_accuracy: 0.5233
# Epoch 23/50
# 39/39 [==============================] - 25s 628ms/step - loss: 0.8755 - accuracy: 0.6386 - val_loss: 0.9682 - val_accuracy: 0.5795
# Epoch 24/50
# 39/39 [==============================] - 25s 631ms/step - loss: 0.8695 - accuracy: 0.6346 - val_loss: 1.0328 - val_accuracy: 0.5682
# Epoch 25/50
# 39/39 [==============================] - 25s 624ms/step - loss: 0.8826 - accuracy: 0.6394 - val_loss: 1.0897 - val_accuracy: 0.6051
# Epoch 26/50
# 39/39 [==============================] - 25s 633ms/step - loss: 0.8670 - accuracy: 0.6414 - val_loss: 1.0965 - val_accuracy: 0.5827
# Epoch 27/50
# 39/39 [==============================] - 25s 629ms/step - loss: 0.8602 - accuracy: 0.6458 - val_loss: 1.0888 - val_accuracy: 0.5682
# Epoch 28/50
# 39/39 [==============================] - 25s 625ms/step - loss: 0.8610 - accuracy: 0.6374 - val_loss: 1.1218 - val_accuracy: 0.5923
# Epoch 29/50
# 39/39 [==============================] - 25s 629ms/step - loss: 0.8520 - accuracy: 0.6394 - val_loss: 1.2120 - val_accuracy: 0.5891
# Epoch 30/50
# 39/39 [==============================] - 25s 635ms/step - loss: 0.8530 - accuracy: 0.6594 - val_loss: 0.9879 - val_accuracy: 0.5923
# Epoch 31/50
# 39/39 [==============================] - 25s 642ms/step - loss: 0.8562 - accuracy: 0.6486 - val_loss: 1.0190 - val_accuracy: 0.5827
# Epoch 32/50
# 39/39 [==============================] - 25s 634ms/step - loss: 0.8399 - accuracy: 0.6390 - val_loss: 0.9161 - val_accuracy: 0.6164
# Epoch 33/50
# 39/39 [==============================] - 25s 630ms/step - loss: 0.8534 - accuracy: 0.6446 - val_loss: 0.9440 - val_accuracy: 0.6164
# Epoch 34/50
# 39/39 [==============================] - 25s 634ms/step - loss: 0.8495 - accuracy: 0.6438 - val_loss: 0.9906 - val_accuracy: 0.6148
# Epoch 35/50
# 39/39 [==============================] - 25s 621ms/step - loss: 0.8368 - accuracy: 0.6506 - val_loss: 0.9050 - val_accuracy: 0.6148
# Epoch 36/50
# 39/39 [==============================] - 25s 633ms/step - loss: 0.8424 - accuracy: 0.6530 - val_loss: 0.9095 - val_accuracy: 0.6388
# Epoch 37/50
# 39/39 [==============================] - 25s 634ms/step - loss: 0.8394 - accuracy: 0.6510 - val_loss: 0.9845 - val_accuracy: 0.6212
# Epoch 38/50
# 39/39 [==============================] - 25s 635ms/step - loss: 0.8467 - accuracy: 0.6482 - val_loss: 1.0142 - val_accuracy: 0.5714
# Epoch 39/50
# 39/39 [==============================] - 25s 630ms/step - loss: 0.8275 - accuracy: 0.6598 - val_loss: 0.9691 - val_accuracy: 0.5907
# Epoch 40/50
# 39/39 [==============================] - 25s 623ms/step - loss: 0.8357 - accuracy: 0.6450 - val_loss: 0.9805 - val_accuracy: 0.5939
# Epoch 41/50
# 39/39 [==============================] - 25s 626ms/step - loss: 0.8242 - accuracy: 0.6538 - val_loss: 0.9532 - val_accuracy: 0.6212
# Epoch 42/50
# 39/39 [==============================] - 25s 622ms/step - loss: 0.8194 - accuracy: 0.6550 - val_loss: 0.9401 - val_accuracy: 0.6212
# Epoch 43/50
# 39/39 [==============================] - 25s 623ms/step - loss: 0.8222 - accuracy: 0.6582 - val_loss: 0.9829 - val_accuracy: 0.6100
# Epoch 44/50
# 39/39 [==============================] - 25s 630ms/step - loss: 0.8223 - accuracy: 0.6526 - val_loss: 0.9744 - val_accuracy: 0.6212
# Epoch 45/50
# 39/39 [==============================] - 25s 632ms/step - loss: 0.8227 - accuracy: 0.6606 - val_loss: 0.9377 - val_accuracy: 0.6019
# Epoch 46/50
# 39/39 [==============================] - 25s 637ms/step - loss: 0.8126 - accuracy: 0.6542 - val_loss: 0.9852 - val_accuracy: 0.6067
# Epoch 47/50
# 39/39 [==============================] - 25s 626ms/step - loss: 0.8234 - accuracy: 0.6510 - val_loss: 0.9697 - val_accuracy: 0.6276
# Epoch 48/50
# 39/39 [==============================] - 25s 626ms/step - loss: 0.8277 - accuracy: 0.6578 - val_loss: 1.0393 - val_accuracy: 0.5666
# Epoch 49/50
# 39/39 [==============================] - 25s 622ms/step - loss: 0.8183 - accuracy: 0.6615 - val_loss: 1.2243 - val_accuracy: 0.5811
# Epoch 50/50
# 39/39 [==============================] - 25s 627ms/step - loss: 0.8369 - accuracy: 0.6554 - val_loss: 0.9614 - val_accuracy: 0.6276

# %%
score = model.evaluate(datagen.flow(X_test, y_test), verbose=0)
print('Test loss:', score)
# Out:
# Test loss: [0.9585037231445312, 0.6297640800476074]

# %%
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Loss Curves')

# %%
class_names = ['Residnetial', 'Commercial', 'Industrial','Speical']
images_and_labels = list(zip(X_test, y_test))
plt.figure(figsize=(30,30))
for index, (image, label) in enumerate(images_and_labels):
    plt.subplot(4, 10, index + 1)
    plt.axis('off')
    plt.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')
    index = np.where(label == 1)
    imagedata = image[np.newaxis, :, :]
    pred = model.predict(imagedata)
    pred= pred[0].argmax(axis=0)
    plt.title(class_names[pred])
plt.show()
