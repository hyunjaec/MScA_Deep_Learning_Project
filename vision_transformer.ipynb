# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunjaec/MScA_Deep_Learning_Project/blob/main/vision_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
from scipy import ndimage, signal as sg
from skimage import data, filters, io, color
from sklearn.model_selection import train_test_split
from PIL import Image
import glob
import cv2
from google.colab.patches import cv2_imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras import layers
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten,BatchNormalization, Input, ZeroPadding2D
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
# !pwd
# Out:
# /content

# %%
#connect colab with google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#label csv
austin_df = pd.read_csv("/content/drive/My Drive/Data/data/austin.csv")
austin_df = austin_df.drop('Unnamed: 0', axis = 1)
austin_df.head()
# Out:
#           image_name  zoning_id zoning_zty
# 0  data/austin_0.jpg     229791        PUD
# 1  data/austin_1.jpg     229791        PUD
# 2  data/austin_2.jpg  400523442       I-RR
# 3  data/austin_3.jpg     229791        PUD
# 4  data/austin_4.jpg     229791        PUD

# %%
residential = ['LA',
            'RR',
            'SF-1',
            'SF-2',
            'SF-3',
            'SF-4A',
            'SF-4-A,'
            'SF-4B',
            'SF-5',
            'SF-6',
            'MF-1',
            'MF-2',
            'MF-3',
            'MF-4',
            'MF-5',
            'MF-6',
            'MF-CO',
            'MH']

commercial = ['NO',
            'LO',
            'GO',
            'CR',
            'LR',
            'GR',
            'L',
            'CBD',
            'DMU',
            'W/LO',
            'CS',
            'CS-1',
            'CH']

industrial = ['IP', 'LI', 'MI', 'R&D']

special = ['DR', 'AV', 'AG', 'P', 'PUD', 'TN', 'ERC', 'UNZ']

# %%
#loop through list of zone codes, map specific zone codes to R, C, I, or S
austin_df.loc[:, 'zone'] = np.nan

for i in residential:
    austin_df.loc[:, 'zone'] = np.where(austin_df.loc[:, 'zoning_zty'].str.contains(i) == True, 
                                     'R', austin_df.loc[:,'zone'])
for i in industrial:
    austin_df.loc[:, 'zone'] = np.where(((austin_df.loc[:, 'zoning_zty'].str.contains(i) == True) & (austin_df.loc[:, 'zone'] != 'R')), 
                                     'I', austin_df.loc[:,'zone'])
for i in commercial:
    austin_df.loc[:, 'zone'] = np.where((austin_df.loc[:, 'zoning_zty'].str.contains(i) == True) & \
                                     (austin_df.loc[:, 'zone'] != 'R') & (austin_df.loc[:, 'zone'] != 'I'), 
                                     'C', austin_df.loc[:,'zone'])
for i in special:
    austin_df.loc[:, 'zone'] = np.where((austin_df.loc[:, 'zoning_zty'].str.contains(i) == True) & \
                                     (austin_df.loc[:, 'zone'] != 'I') & (austin_df.loc[:, 'zone'] != 'R') &\
                                     (austin_df.loc[:, 'zone'] != 'C'), 
                                     'S', austin_df.loc[:,'zone'])

# %%
#manually set this one
austin_df.loc[303, 'zone'] = 'R'

# %%
img_names = austin_df['image_name']

# %%
dim = (300, 300)
# img_df = []
# for i in img_names:
#   img_df.append(cv2.imread("/content/drive/My Drive/Data/" + str(i[:-4])+".jpg"))
img_df = []
# for i in img_names:
#     img_df.append(cv2.imread(('../'+ str(i))))
for i, img in enumerate(img_names):
    visual_img = image.load_img(('/content/drive/My Drive/Data/'+img), target_size=dim)
    img_array = image.img_to_array(visual_img)
    img_df.append(img_array)

# %%
#make images equal pixel by 500, 500 
# for i, img in enumerate(img_df):
#   img_df[i] = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

# %%
zone_class = austin_df['zone']

# %%
zone_class = pd.factorize(zone_class)[0]
zone_class
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
img_df2 = np.array(img_df) 
#split labels and images for train&test
X_train, X_test, y_train, y_test = train_test_split(img_df2, zone_class, test_size=.2)
input_shape = (300, 300, 3)

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
import matplotlib.pyplot as plt
image_size = 72  
patch_size = 16
plt.figure(figsize=(4, 4))
image = X_train[np.random.choice(range(X_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 72 X 72
# Patch size: 16 X 16
# Patches per image: 16
# Elements per patch: 768

# %%
import sys
sys.path.append('/content/sample_data/')

# %%
#!pip install tensorflow_addons

# %%
from vit_model import VisionTransformer

# %%
X_train = X_train.astype("float32")/255
X_test = X_test.astype("float32")/255

# %%
input_shape=X_train.shape[1:]
learning_rate = 0.001
weight_decay = 0.001
batch_size = 256
num_epochs = 100
image_size = 72
patch_size = 6
projection_dim = 64
num_attention_heads = 4
num_transformer_layers = 8
num_mlp_heads = [2048, 1024]
output_classes = len(np.unique(y_train))

# %%
transformer = VisionTransformer(
    input_shape=input_shape, 
    image_size=image_size, 
    patch_size=patch_size, 
    projection_dim=projection_dim, 
    num_transformer_layers=num_transformer_layers,
    num_attention_heads=num_attention_heads,
    num_mlp_heads=num_mlp_heads,
    output_classes=output_classes
    )

# %%
def train(model, X_train, y_train, batch_size, epochs, learning_rate, weight_decay):
    model.summary()

    model.compile(learning_rate=learning_rate, weight_decay=weight_decay)

    model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs)

    return model

# %%
trained_transformer = train(transformer, X_train, y_train, batch_size, num_epochs, learning_rate, weight_decay)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 300, 300, 3  0           []
#                                 )]
#
#  resizing (Resizing)            (None, 72, 72, 3)    0           ['input_1[0][0]']
#
#  patches_1 (Patches)            (None, None, 108)    0           ['resizing[0][0]']
#
#  patch_encoder (PatchEncoder)   (None, 144, 64)      16192       ['patches_1[0][0]']
#
#  layer_normalization (LayerNorm  (None, 144, 64)     128         ['patch_encoder[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 144, 64)     66368       ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  add (Add)                      (None, 144, 64)      0           ['multi_head_attention[0][0]',
#                                                                   'patch_encoder[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 144, 64)     128         ['add[0][0]']
#  rmalization)
#
#  dense_1 (Dense)                (None, 144, 128)     8320        ['layer_normalization_1[0][0]']
#
#  gelu (GELU)                    (None, 144, 128)     0           ['dense_1[0][0]']
#
#  dropout (Dropout)              (None, 144, 128)     0           ['gelu[0][0]']
#
#  dense_2 (Dense)                (None, 144, 64)      8256        ['dropout[0][0]']
#
#  gelu_1 (GELU)                  (None, 144, 64)      0           ['dense_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 144, 64)      0           ['gelu_1[0][0]']
#
#  add_1 (Add)                    (None, 144, 64)      0           ['dropout_1[0][0]',
#                                                                   'add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 144, 64)     128         ['add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 144, 64)     66368       ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  add_2 (Add)                    (None, 144, 64)      0           ['multi_head_attention_1[0][0]',
#                                                                   'add_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 144, 64)     128         ['add_2[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 144, 128)     8320        ['layer_normalization_3[0][0]']
#
#  gelu_2 (GELU)                  (None, 144, 128)     0           ['dense_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 144, 128)     0           ['gelu_2[0][0]']
#
#  dense_4 (Dense)                (None, 144, 64)      8256        ['dropout_2[0][0]']
#
#  gelu_3 (GELU)                  (None, 144, 64)      0           ['dense_4[0][0]']
#
#  dropout_3 (Dropout)            (None, 144, 64)      0           ['gelu_3[0][0]']
#
#  add_3 (Add)                    (None, 144, 64)      0           ['dropout_3[0][0]',
#                                                                   'add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 144, 64)     128         ['add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 144, 64)     66368       ['layer_normalization_4[0][0]',
#  eadAttention)                                                    'layer_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 144, 64)      0           ['multi_head_attention_2[0][0]',
#                                                                   'add_3[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 144, 64)     128         ['add_4[0][0]']
#  rmalization)
#
#  dense_5 (Dense)                (None, 144, 128)     8320        ['layer_normalization_5[0][0]']
#
#  gelu_4 (GELU)                  (None, 144, 128)     0           ['dense_5[0][0]']
#
#  dropout_4 (Dropout)            (None, 144, 128)     0           ['gelu_4[0][0]']
#
#  dense_6 (Dense)                (None, 144, 64)      8256        ['dropout_4[0][0]']
#
#  gelu_5 (GELU)                  (None, 144, 64)      0           ['dense_6[0][0]']
#
#  dropout_5 (Dropout)            (None, 144, 64)      0           ['gelu_5[0][0]']
#
#  add_5 (Add)                    (None, 144, 64)      0           ['dropout_5[0][0]',
#                                                                   'add_4[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 144, 64)     128         ['add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 144, 64)     66368       ['layer_normalization_6[0][0]',
#  eadAttention)                                                    'layer_normalization_6[0][0]']
#
#  add_6 (Add)                    (None, 144, 64)      0           ['multi_head_attention_3[0][0]',
#                                                                   'add_5[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 144, 64)     128         ['add_6[0][0]']
#  rmalization)
#
#  dense_7 (Dense)                (None, 144, 128)     8320        ['layer_normalization_7[0][0]']
#
#  gelu_6 (GELU)                  (None, 144, 128)     0           ['dense_7[0][0]']
#
#  dropout_6 (Dropout)            (None, 144, 128)     0           ['gelu_6[0][0]']
#
#  dense_8 (Dense)                (None, 144, 64)      8256        ['dropout_6[0][0]']
#
#  gelu_7 (GELU)                  (None, 144, 64)      0           ['dense_8[0][0]']
#
#  dropout_7 (Dropout)            (None, 144, 64)      0           ['gelu_7[0][0]']
#
#  add_7 (Add)                    (None, 144, 64)      0           ['dropout_7[0][0]',
#                                                                   'add_6[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 144, 64)     128         ['add_7[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (None, 144, 64)     66368       ['layer_normalization_8[0][0]',
#  eadAttention)                                                    'layer_normalization_8[0][0]']
#
#  add_8 (Add)                    (None, 144, 64)      0           ['multi_head_attention_4[0][0]',
#                                                                   'add_7[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 144, 64)     128         ['add_8[0][0]']
#  rmalization)
#
#  dense_9 (Dense)                (None, 144, 128)     8320        ['layer_normalization_9[0][0]']
#
#  gelu_8 (GELU)                  (None, 144, 128)     0           ['dense_9[0][0]']
#
#  dropout_8 (Dropout)            (None, 144, 128)     0           ['gelu_8[0][0]']
#
#  dense_10 (Dense)               (None, 144, 64)      8256        ['dropout_8[0][0]']
#
#  gelu_9 (GELU)                  (None, 144, 64)      0           ['dense_10[0][0]']
#
#  dropout_9 (Dropout)            (None, 144, 64)      0           ['gelu_9[0][0]']
#
#  add_9 (Add)                    (None, 144, 64)      0           ['dropout_9[0][0]',
#                                                                   'add_8[0][0]']
#
#  layer_normalization_10 (LayerN  (None, 144, 64)     128         ['add_9[0][0]']
#  ormalization)
#
#  multi_head_attention_5 (MultiH  (None, 144, 64)     66368       ['layer_normalization_10[0][0]',
#  eadAttention)                                                    'layer_normalization_10[0][0]']
#
#  add_10 (Add)                   (None, 144, 64)      0           ['multi_head_attention_5[0][0]',
#                                                                   'add_9[0][0]']
#
#  layer_normalization_11 (LayerN  (None, 144, 64)     128         ['add_10[0][0]']
#  ormalization)
#
#  dense_11 (Dense)               (None, 144, 128)     8320        ['layer_normalization_11[0][0]']
#
#  gelu_10 (GELU)                 (None, 144, 128)     0           ['dense_11[0][0]']
#
#  dropout_10 (Dropout)           (None, 144, 128)     0           ['gelu_10[0][0]']
#
#  dense_12 (Dense)               (None, 144, 64)      8256        ['dropout_10[0][0]']
#
#  gelu_11 (GELU)                 (None, 144, 64)      0           ['dense_12[0][0]']
#
#  dropout_11 (Dropout)           (None, 144, 64)      0           ['gelu_11[0][0]']
#
#  add_11 (Add)                   (None, 144, 64)      0           ['dropout_11[0][0]',
#                                                                   'add_10[0][0]']
#
#  layer_normalization_12 (LayerN  (None, 144, 64)     128         ['add_11[0][0]']
#  ormalization)
#
#  multi_head_attention_6 (MultiH  (None, 144, 64)     66368       ['layer_normalization_12[0][0]',
#  eadAttention)                                                    'layer_normalization_12[0][0]']
#
#  add_12 (Add)                   (None, 144, 64)      0           ['multi_head_attention_6[0][0]',
#                                                                   'add_11[0][0]']
#
#  layer_normalization_13 (LayerN  (None, 144, 64)     128         ['add_12[0][0]']
#  ormalization)
#
#  dense_13 (Dense)               (None, 144, 128)     8320        ['layer_normalization_13[0][0]']
#
#  gelu_12 (GELU)                 (None, 144, 128)     0           ['dense_13[0][0]']
#
#  dropout_12 (Dropout)           (None, 144, 128)     0           ['gelu_12[0][0]']
#
#  dense_14 (Dense)               (None, 144, 64)      8256        ['dropout_12[0][0]']
#
#  gelu_13 (GELU)                 (None, 144, 64)      0           ['dense_14[0][0]']
#
#  dropout_13 (Dropout)           (None, 144, 64)      0           ['gelu_13[0][0]']
#
#  add_13 (Add)                   (None, 144, 64)      0           ['dropout_13[0][0]',
#                                                                   'add_12[0][0]']
#
#  layer_normalization_14 (LayerN  (None, 144, 64)     128         ['add_13[0][0]']
#  ormalization)
#
#  multi_head_attention_7 (MultiH  (None, 144, 64)     66368       ['layer_normalization_14[0][0]',
#  eadAttention)                                                    'layer_normalization_14[0][0]']
#
#  add_14 (Add)                   (None, 144, 64)      0           ['multi_head_attention_7[0][0]',
#                                                                   'add_13[0][0]']
#
#  layer_normalization_15 (LayerN  (None, 144, 64)     128         ['add_14[0][0]']
#  ormalization)
#
#  dense_15 (Dense)               (None, 144, 128)     8320        ['layer_normalization_15[0][0]']
#
#  gelu_14 (GELU)                 (None, 144, 128)     0           ['dense_15[0][0]']
#
#  dropout_14 (Dropout)           (None, 144, 128)     0           ['gelu_14[0][0]']
#
#  dense_16 (Dense)               (None, 144, 64)      8256        ['dropout_14[0][0]']
#
#  gelu_15 (GELU)                 (None, 144, 64)      0           ['dense_16[0][0]']
#
#  dropout_15 (Dropout)           (None, 144, 64)      0           ['gelu_15[0][0]']
#
#  add_15 (Add)                   (None, 144, 64)      0           ['dropout_15[0][0]',
#                                                                   'add_14[0][0]']
#
#  layer_normalization_16 (LayerN  (None, 144, 64)     128         ['add_15[0][0]']
#  ormalization)
#
#  flatten (Flatten)              (None, 9216)         0           ['layer_normalization_16[0][0]']
#
#  dropout_16 (Dropout)           (None, 9216)         0           ['flatten[0][0]']
#
#  dense_17 (Dense)               (None, 2048)         18876416    ['dropout_16[0][0]']
#
#  gelu_16 (GELU)                 (None, 2048)         0           ['dense_17[0][0]']
#
#  dropout_17 (Dropout)           (None, 2048)         0           ['gelu_16[0][0]']
#
#  dense_18 (Dense)               (None, 1024)         2098176     ['dropout_17[0][0]']
#
#  gelu_17 (GELU)                 (None, 1024)         0           ['dense_18[0][0]']
#
#  dropout_18 (Dropout)           (None, 1024)         0           ['gelu_17[0][0]']
#
#  dense_19 (Dense)               (None, 4)            4100        ['dropout_18[0][0]']
#
# ==================================================================================================
# Total params: 21,660,612
# Trainable params: 21,660,612
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 12/12 [==============================] - 17s 294ms/step - loss: 11.2626 - accuracy: 0.3580 - top-5-accuracy: 1.0000
# Epoch 2/100
# 12/12 [==============================] - 3s 287ms/step - loss: 1.7063 - accuracy: 0.4095 - top-5-accuracy: 1.0000
# Epoch 3/100
# 12/12 [==============================] - 3s 289ms/step - loss: 1.2553 - accuracy: 0.4057 - top-5-accuracy: 1.0000
# Epoch 4/100
# 12/12 [==============================] - 4s 292ms/step - loss: 1.2071 - accuracy: 0.4436 - top-5-accuracy: 1.0000
# Epoch 5/100
# 12/12 [==============================] - 4s 301ms/step - loss: 1.1961 - accuracy: 0.4350 - top-5-accuracy: 1.0000
# Epoch 6/100
# 12/12 [==============================] - 4s 304ms/step - loss: 1.1891 - accuracy: 0.4490 - top-5-accuracy: 1.0000
# Epoch 7/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.1815 - accuracy: 0.4487 - top-5-accuracy: 1.0000
# Epoch 8/100
# 12/12 [==============================] - 4s 293ms/step - loss: 1.1839 - accuracy: 0.4483 - top-5-accuracy: 1.0000
# Epoch 9/100
# 12/12 [==============================] - 3s 287ms/step - loss: 1.1739 - accuracy: 0.4599 - top-5-accuracy: 1.0000
# Epoch 10/100
# 12/12 [==============================] - 3s 286ms/step - loss: 1.1700 - accuracy: 0.4640 - top-5-accuracy: 1.0000
# Epoch 11/100
# 12/12 [==============================] - 3s 290ms/step - loss: 1.1592 - accuracy: 0.4691 - top-5-accuracy: 1.0000
# Epoch 12/100
# 12/12 [==============================] - 3s 285ms/step - loss: 1.1649 - accuracy: 0.4610 - top-5-accuracy: 1.0000
# Epoch 13/100
# 12/12 [==============================] - 3s 287ms/step - loss: 1.1549 - accuracy: 0.4729 - top-5-accuracy: 1.0000
# Epoch 14/100
# 12/12 [==============================] - 3s 287ms/step - loss: 1.1457 - accuracy: 0.4770 - top-5-accuracy: 1.0000
# Epoch 15/100
# 12/12 [==============================] - 4s 292ms/step - loss: 1.1353 - accuracy: 0.4818 - top-5-accuracy: 1.0000
# Epoch 16/100
# 12/12 [==============================] - 3s 290ms/step - loss: 1.1329 - accuracy: 0.4783 - top-5-accuracy: 1.0000
# Epoch 17/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.1274 - accuracy: 0.4760 - top-5-accuracy: 1.0000
# Epoch 18/100
# 12/12 [==============================] - 3s 290ms/step - loss: 1.0994 - accuracy: 0.4872 - top-5-accuracy: 1.0000
# Epoch 19/100
# 12/12 [==============================] - 3s 285ms/step - loss: 1.1003 - accuracy: 0.4838 - top-5-accuracy: 1.0000
# Epoch 20/100
# 12/12 [==============================] - 3s 287ms/step - loss: 1.1018 - accuracy: 0.4893 - top-5-accuracy: 1.0000
# Epoch 21/100
# 12/12 [==============================] - 3s 285ms/step - loss: 1.0941 - accuracy: 0.4835 - top-5-accuracy: 1.0000
# Epoch 22/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.0871 - accuracy: 0.4859 - top-5-accuracy: 1.0000
# Epoch 23/100
# 12/12 [==============================] - 3s 287ms/step - loss: 1.0800 - accuracy: 0.4920 - top-5-accuracy: 1.0000
# Epoch 24/100
# 12/12 [==============================] - 3s 287ms/step - loss: 1.0945 - accuracy: 0.4882 - top-5-accuracy: 1.0000
# Epoch 25/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.0784 - accuracy: 0.4998 - top-5-accuracy: 1.0000
# Epoch 26/100
# 12/12 [==============================] - 3s 287ms/step - loss: 1.0785 - accuracy: 0.4923 - top-5-accuracy: 1.0000
# Epoch 27/100
# 12/12 [==============================] - 3s 285ms/step - loss: 1.0795 - accuracy: 0.4930 - top-5-accuracy: 1.0000
# Epoch 28/100
# 12/12 [==============================] - 3s 286ms/step - loss: 1.0870 - accuracy: 0.4947 - top-5-accuracy: 1.0000
# Epoch 29/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.0802 - accuracy: 0.4968 - top-5-accuracy: 1.0000
# Epoch 30/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.0771 - accuracy: 0.5022 - top-5-accuracy: 1.0000
# Epoch 31/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.0624 - accuracy: 0.5026 - top-5-accuracy: 1.0000
# Epoch 32/100
# 12/12 [==============================] - 4s 292ms/step - loss: 1.0664 - accuracy: 0.4995 - top-5-accuracy: 1.0000
# Epoch 33/100
# 12/12 [==============================] - 3s 289ms/step - loss: 1.0648 - accuracy: 0.5009 - top-5-accuracy: 1.0000
# Epoch 34/100
# 12/12 [==============================] - 3s 289ms/step - loss: 1.0639 - accuracy: 0.5002 - top-5-accuracy: 1.0000
# Epoch 35/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.0701 - accuracy: 0.4985 - top-5-accuracy: 1.0000
# Epoch 36/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.0599 - accuracy: 0.5077 - top-5-accuracy: 1.0000
# Epoch 37/100
# 12/12 [==============================] - 4s 290ms/step - loss: 1.0559 - accuracy: 0.5199 - top-5-accuracy: 1.0000
# Epoch 38/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.0486 - accuracy: 0.5073 - top-5-accuracy: 1.0000
# Epoch 39/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.0587 - accuracy: 0.5087 - top-5-accuracy: 1.0000
# Epoch 40/100
# 12/12 [==============================] - 4s 291ms/step - loss: 1.0593 - accuracy: 0.5012 - top-5-accuracy: 1.0000
# Epoch 41/100
# 12/12 [==============================] - 3s 286ms/step - loss: 1.0528 - accuracy: 0.5121 - top-5-accuracy: 1.0000
# Epoch 42/100
# 12/12 [==============================] - 3s 286ms/step - loss: 1.0561 - accuracy: 0.5162 - top-5-accuracy: 1.0000
# Epoch 43/100
# 12/12 [==============================] - 4s 291ms/step - loss: 1.0354 - accuracy: 0.5373 - top-5-accuracy: 1.0000
# Epoch 44/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.0424 - accuracy: 0.5254 - top-5-accuracy: 1.0000
# Epoch 45/100
# 12/12 [==============================] - 3s 287ms/step - loss: 1.0399 - accuracy: 0.5309 - top-5-accuracy: 1.0000
# Epoch 46/100
# 12/12 [==============================] - 3s 286ms/step - loss: 1.0330 - accuracy: 0.5424 - top-5-accuracy: 1.0000
# Epoch 47/100
# 12/12 [==============================] - 3s 290ms/step - loss: 1.0322 - accuracy: 0.5424 - top-5-accuracy: 1.0000
# Epoch 48/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.0174 - accuracy: 0.5517 - top-5-accuracy: 1.0000
# Epoch 49/100
# 12/12 [==============================] - 3s 289ms/step - loss: 1.0370 - accuracy: 0.5268 - top-5-accuracy: 1.0000
# Epoch 50/100
# 12/12 [==============================] - 3s 290ms/step - loss: 1.0447 - accuracy: 0.5295 - top-5-accuracy: 1.0000
# Epoch 51/100
# 12/12 [==============================] - 3s 289ms/step - loss: 1.0211 - accuracy: 0.5527 - top-5-accuracy: 1.0000
# Epoch 52/100
# 12/12 [==============================] - 3s 287ms/step - loss: 1.0078 - accuracy: 0.5673 - top-5-accuracy: 1.0000
# Epoch 53/100
# 12/12 [==============================] - 3s 291ms/step - loss: 1.0163 - accuracy: 0.5632 - top-5-accuracy: 1.0000
# Epoch 54/100
# 12/12 [==============================] - 4s 291ms/step - loss: 0.9991 - accuracy: 0.5673 - top-5-accuracy: 1.0000
# Epoch 55/100
# 12/12 [==============================] - 3s 289ms/step - loss: 1.0072 - accuracy: 0.5735 - top-5-accuracy: 1.0000
# Epoch 56/100
# 12/12 [==============================] - 4s 296ms/step - loss: 1.0054 - accuracy: 0.5721 - top-5-accuracy: 1.0000
# Epoch 57/100
# 12/12 [==============================] - 3s 289ms/step - loss: 0.9796 - accuracy: 0.5834 - top-5-accuracy: 1.0000
# Epoch 58/100
# 12/12 [==============================] - 3s 287ms/step - loss: 0.9955 - accuracy: 0.5745 - top-5-accuracy: 1.0000
# Epoch 59/100
# 12/12 [==============================] - 3s 288ms/step - loss: 0.9856 - accuracy: 0.5759 - top-5-accuracy: 1.0000
# Epoch 60/100
# 12/12 [==============================] - 3s 288ms/step - loss: 1.0054 - accuracy: 0.5612 - top-5-accuracy: 1.0000
# Epoch 61/100
# 12/12 [==============================] - 3s 287ms/step - loss: 0.9884 - accuracy: 0.5776 - top-5-accuracy: 1.0000
# Epoch 62/100
# 12/12 [==============================] - 4s 292ms/step - loss: 0.9660 - accuracy: 0.5922 - top-5-accuracy: 1.0000
# Epoch 63/100
# 12/12 [==============================] - 3s 290ms/step - loss: 0.9578 - accuracy: 0.6011 - top-5-accuracy: 1.0000
# Epoch 64/100
# 12/12 [==============================] - 3s 288ms/step - loss: 0.9531 - accuracy: 0.6008 - top-5-accuracy: 1.0000
# Epoch 65/100
# 12/12 [==============================] - 3s 290ms/step - loss: 0.9325 - accuracy: 0.6140 - top-5-accuracy: 1.0000
# Epoch 66/100
# 12/12 [==============================] - 3s 284ms/step - loss: 0.9575 - accuracy: 0.6042 - top-5-accuracy: 1.0000
# Epoch 67/100
# 12/12 [==============================] - 3s 286ms/step - loss: 0.9537 - accuracy: 0.6014 - top-5-accuracy: 1.0000
# Epoch 68/100
# 12/12 [==============================] - 3s 290ms/step - loss: 0.9181 - accuracy: 0.6263 - top-5-accuracy: 1.0000
# Epoch 69/100
# 12/12 [==============================] - 3s 289ms/step - loss: 0.9314 - accuracy: 0.6130 - top-5-accuracy: 1.0000
# Epoch 70/100
# 12/12 [==============================] - 3s 287ms/step - loss: 0.8971 - accuracy: 0.6352 - top-5-accuracy: 1.0000
# Epoch 71/100
# 12/12 [==============================] - 3s 286ms/step - loss: 0.8928 - accuracy: 0.6430 - top-5-accuracy: 1.0000
# Epoch 72/100
# 12/12 [==============================] - 3s 287ms/step - loss: 0.8531 - accuracy: 0.6584 - top-5-accuracy: 1.0000
# Epoch 73/100
# 12/12 [==============================] - 3s 287ms/step - loss: 0.8633 - accuracy: 0.6519 - top-5-accuracy: 1.0000
# Epoch 74/100
# 12/12 [==============================] - 3s 290ms/step - loss: 0.8122 - accuracy: 0.6826 - top-5-accuracy: 1.0000
# Epoch 75/100
# 12/12 [==============================] - 3s 289ms/step - loss: 0.8632 - accuracy: 0.6543 - top-5-accuracy: 1.0000
# Epoch 76/100
# 12/12 [==============================] - 3s 288ms/step - loss: 0.7943 - accuracy: 0.6962 - top-5-accuracy: 1.0000
# Epoch 77/100
# 12/12 [==============================] - 3s 288ms/step - loss: 0.7786 - accuracy: 0.7054 - top-5-accuracy: 1.0000
# Epoch 78/100
# 12/12 [==============================] - 3s 288ms/step - loss: 0.8273 - accuracy: 0.6833 - top-5-accuracy: 1.0000
# Epoch 79/100
# 12/12 [==============================] - 3s 288ms/step - loss: 0.7634 - accuracy: 0.7085 - top-5-accuracy: 1.0000
# Epoch 80/100
# 12/12 [==============================] - 3s 286ms/step - loss: 0.7018 - accuracy: 0.7375 - top-5-accuracy: 1.0000
# Epoch 81/100
# 12/12 [==============================] - 3s 288ms/step - loss: 0.6841 - accuracy: 0.7518 - top-5-accuracy: 1.0000
# Epoch 82/100
# 12/12 [==============================] - 3s 289ms/step - loss: 0.6787 - accuracy: 0.7422 - top-5-accuracy: 1.0000
# Epoch 83/100
# 12/12 [==============================] - 3s 287ms/step - loss: 0.6951 - accuracy: 0.7439 - top-5-accuracy: 1.0000
# Epoch 84/100
# 12/12 [==============================] - 3s 291ms/step - loss: 0.6555 - accuracy: 0.7586 - top-5-accuracy: 1.0000
# Epoch 85/100
# 12/12 [==============================] - 3s 289ms/step - loss: 0.6303 - accuracy: 0.7624 - top-5-accuracy: 1.0000
# Epoch 86/100
# 12/12 [==============================] - 3s 288ms/step - loss: 0.5491 - accuracy: 0.8115 - top-5-accuracy: 1.0000
# Epoch 87/100
# 12/12 [==============================] - 3s 288ms/step - loss: 0.5234 - accuracy: 0.8210 - top-5-accuracy: 1.0000
# Epoch 88/100
# 12/12 [==============================] - 3s 288ms/step - loss: 0.5515 - accuracy: 0.8057 - top-5-accuracy: 1.0000
# Epoch 89/100
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4781 - accuracy: 0.8350 - top-5-accuracy: 1.0000
# Epoch 90/100
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4604 - accuracy: 0.8432 - top-5-accuracy: 1.0000
# Epoch 91/100
# 12/12 [==============================] - 3s 289ms/step - loss: 0.5435 - accuracy: 0.7961 - top-5-accuracy: 1.0000
# Epoch 92/100
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4378 - accuracy: 0.8565 - top-5-accuracy: 1.0000
# Epoch 93/100
# 12/12 [==============================] - 3s 286ms/step - loss: 0.3919 - accuracy: 0.8708 - top-5-accuracy: 1.0000
# Epoch 94/100
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4083 - accuracy: 0.8646 - top-5-accuracy: 1.0000
# Epoch 95/100
# 12/12 [==============================] - 3s 288ms/step - loss: 0.3983 - accuracy: 0.8681 - top-5-accuracy: 1.0000
# Epoch 96/100
# 12/12 [==============================] - 3s 288ms/step - loss: 0.3683 - accuracy: 0.8776 - top-5-accuracy: 1.0000
# Epoch 97/100
# 12/12 [==============================] - 3s 287ms/step - loss: 0.3620 - accuracy: 0.8756 - top-5-accuracy: 1.0000
# Epoch 98/100
# 12/12 [==============================] - 4s 291ms/step - loss: 0.4078 - accuracy: 0.8619 - top-5-accuracy: 1.0000
# Epoch 99/100
# 12/12 [==============================] - 3s 290ms/step - loss: 0.3639 - accuracy: 0.8831 - top-5-accuracy: 1.0000
# Epoch 100/100
# 12/12 [==============================] - 3s 285ms/step - loss: 0.3249 - accuracy: 0.8895 - top-5-accuracy: 1.0000

# %%
score = trained_transformer.evaluate(X_test, y_test)
print('Test loss:', score)
# Out:
# 23/23 [==============================] - 1s 33ms/step - loss: 1.6985 - accuracy: 0.5586 - top-5-accuracy: 1.0000
# Test loss: [1.6985048055648804, 0.5585830807685852, 1.0]
